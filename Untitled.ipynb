# %%
import pandas as pd

# %%
countries = pd.read_csv('countries.csv')
confirmed = pd.read_csv('generated/confirmed.csv')

# %%
merged = confirmed.merge(countries, how='left', left_on='Country/Region', right_on='country')

# %%
merged[merged['country'].isnull()]
# Out:
#                        Country/Region  population        Lat        Long  \
# 43                     Czech Republic    10689209  49.817500   15.473000
# 44   Democratic Republic of the Congo    86790567  -4.038300   21.758700
# 82                        Ivory Coast    25716544   7.540000   -5.547100
# 91                               Laos     7169455  19.856270  102.495496
# 122                   North Macedonia     2083459  41.608600   21.745300
# 135                            Russia   145872256  60.000000   90.000000
# 152                       South Korea    51225308  36.000000  128.000000
# 156                State of Palestine     4981420  31.952200   35.233200
# 161                             Syria    17070135  34.802075   38.996815
# 163                          Tanzania    58005463  -6.369000   34.888800
# 174                     United States   329064917  37.090200  -95.712900
# 177                      Vatican City         799  41.902900   12.453400
# ...
